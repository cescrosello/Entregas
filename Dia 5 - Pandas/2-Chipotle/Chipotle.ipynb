# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv) and assign it to a variable called chipo.

# %%
chip = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",sep = "\t")
chip
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 3. Name of the max valued product

# %%
chip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
chip.sort_values("item_price")
# Out:
#       order_id  quantity            item_name  \
# 261        113         1          Canned Soda
# 1805       730         1          Canned Soda
# 1030       424         1          Canned Soda
# 3020      1201         1          Canned Soda
# 3021      1201         1        Bottled Water
# ...        ...       ...                  ...
# 4547      1807         1     Steak Salad Bowl
# 4391      1752         1     Steak Salad Bowl
# 2600      1032         1     Steak Salad Bowl
# 4241      1693         1     Steak Salad Bowl
# 4390      1751         1  Barbacoa Salad Bowl
#
#                                      choice_description item_price
# 261                                      [Mountain Dew]     $1.09
# 1805                                           [Sprite]     $1.09
# 1030                                  [Diet Dr. Pepper]     $1.09
# 3020                                  [Diet Dr. Pepper]     $1.09
# 3021                                                NaN     $1.09
# ...

# %%
chip["item_price"] = chip["item_price"].str[1:].astype(float)
chip
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
chip_max = chip.sort_values(by= "item_price", ascending= False)

chip_max[0:1]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
mask = chip['item_price'] > 10
mask
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 4617     True
# 4618     True
# 4619     True
# 4620    False
# 4621    False
# Name: item_price, Length: 4622, dtype: bool

# %%
chip_mayor10 = chip.loc[mask,:]

print(f"De un total de {chip.shape[0]}, {chip_mayor10.shape[0]} son mayores a 10$.")
chip_mayor10
# Out:
# De un total de 4622, 1130 son mayores a 10$.
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 13           7         1        Chicken Bowl
# 23          12         1     Chicken Burrito
# ...        ...       ...                 ...
# 4610      1830         1       Steak Burrito
# 4611      1830         1      Veggie Burrito
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# ...

# %% [markdown]
# Extra: Cuántos pedidos se han hecho con un producto de más de 10$

# %%
mask_ud = chip["quantity"] == 1
chip_ud = chip.loc[mask_ud,:]
chip_ud = chip_ud.loc[mask,:]
print(f"Se han realizado un total de {chip_ud.shape[0]} pedidos de 1 ud. con valor mayor a 10$.")
chip_ud
# Out:
# Se han realizado un total de 997 pedidos de 1 ud. con valor mayor a 10$.
#       order_id  quantity           item_name  \
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 13           7         1        Chicken Bowl
# 23          12         1     Chicken Burrito
# 39          19         1       Barbacoa Bowl
# ...        ...       ...                 ...
# 4610      1830         1       Steak Burrito
# 4611      1830         1      Veggie Burrito
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# ...

# %% [markdown]
# ### Step 5. What is the price of each item? Get only item_name and unit_price

# %%
# Crea una nueva columna llamada unit_price
chip.loc[:,"unite_price"] = chip.loc[:,"item_price"] / chip.loc[:,"quantity"]
chip
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price  \
# 0                                                   NaN        2.39
# ...

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chip = chip.sort_values(by= "item_name")
chip
# Out:
#       order_id  quantity          item_name  \
# 3614      1448         1  6 Pack Soft Drink
# 1392       566         1  6 Pack Soft Drink
# 3789      1517         1  6 Pack Soft Drink
# 1124       465         1  6 Pack Soft Drink
# 1916       774         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 1699       688         1  Veggie Soft Tacos
# 2384       948         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
# 738        304         1  Veggie Soft Tacos
# 3889      1559         2  Veggie Soft Tacos
#
#                                      choice_description  item_price  \
# 3614                                           [Nestea]        6.49
# 1392                                        [Diet Coke]        6.49
# 3789                                        [Diet Coke]        6.49
# 1124                                             [Coke]        6.49
# 1916                                        [Diet Coke]        6.49
# ...

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered? 2 ways

# %%
chip.sort_values(by= "unite_price", ascending=False).iloc[0]
# Out:
# order_id                                                            644
# quantity                                                              1
# item_name                                              Steak Salad Bowl
# choice_description    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# item_price                                                        11.89
# unite_price                                                       11.89
# Name: 1590, dtype: object

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
mask_salad = chip["item_name"] == "Veggie Salad Bowl"

chip_salad = chip.loc[mask_salad,:]
print(f"La Veggie Salad Bowl se ha pedido un total de {chip_salad.shape[0]} veces")
chip_salad
# Out:
# La Veggie Salad Bowl se ha pedido un total de 18 veces
#       order_id  quantity          item_name  \
# 1316       536         1  Veggie Salad Bowl
# 186         83         1  Veggie Salad Bowl
# 4201      1677         1  Veggie Salad Bowl
# 1884       760         1  Veggie Salad Bowl
# 960        394         1  Veggie Salad Bowl
# 4261      1700         1  Veggie Salad Bowl
# 4541      1805         1  Veggie Salad Bowl
# 2223       896         1  Veggie Salad Bowl
# 3223      1289         1  Veggie Salad Bowl
# 2269       913         1  Veggie Salad Bowl
# 295        128         1  Veggie Salad Bowl
# 3293      1321         1  Veggie Salad Bowl
# 2683      1066         1  Veggie Salad Bowl
# 2156       869         1  Veggie Salad Bowl
# 496        207         1  Veggie Salad Bowl
# 455        195         1  Veggie Salad Bowl
# 4573      1818         1  Veggie Salad Bowl
# 4109      1646         1  Veggie Salad Bowl
#
# ...

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
mask_soda = chip["item_name"] == "Canned Soda"
chip_soda = chip.loc[mask_soda,:]
chip_soda
# Out:
#       order_id  quantity    item_name choice_description  item_price  \
# 117         51         1  Canned Soda  [Diet Dr. Pepper]        1.09
# 2520      1001         1  Canned Soda        [Coca Cola]        1.09
# 1217       496         1  Canned Soda  [Diet Dr. Pepper]        1.09
# 1662       672         1  Canned Soda        [Diet Coke]        1.09
# 3476      1396         1  Canned Soda        [Coca Cola]        1.09
# ...        ...       ...          ...                ...         ...
# 2493       990         1  Canned Soda        [Coca Cola]        1.09
# 821        338         1  Canned Soda        [Coca Cola]        1.09
# 2961      1177         1  Canned Soda           [Sprite]        1.09
# 179         81         1  Canned Soda        [Coca Cola]        1.09
# 378        164         1  Canned Soda     [Mountain Dew]        1.09
#
#       unite_price
# 117          1.09
# 2520         1.09
# 1217         1.09
# 1662         1.09
# 3476         1.09
# ...           ...
# ...

# %%
mask_soda2 = chip_soda["quantity"] >1
mask_soda2
# Out:
# 117     False
# 2520    False
# 1217    False
# 1662    False
# 3476    False
#         ...
# 2493    False
# 821     False
# 2961    False
# 179     False
# 378     False
# Name: quantity, Length: 104, dtype: bool

# %%
chip_soda_morethanone = chip_soda.loc[mask_soda2,:]
print(f"Se han realizado un total de {chip_soda_morethanone.shape[0]} pedidos con mas de una Canned Soda.")
chip_soda_morethanone
# Out:
# Se han realizado un total de 20 pedidos con mas de una Canned Soda.
#       order_id  quantity    item_name choice_description  item_price  \
# 909        376         2  Canned Soda     [Mountain Dew]        2.18
# 3592      1440         2  Canned Soda        [Diet Coke]        2.18
# 1091       450         2  Canned Soda       [Dr. Pepper]        2.18
# 3866      1550         2  Canned Soda     [Mountain Dew]        2.18
# 698        287         2  Canned Soda        [Coca Cola]        2.18
# 700        288         2  Canned Soda        [Coca Cola]        2.18
# 2905      1156         2  Canned Soda        [Coca Cola]        2.18
# 352        151         2  Canned Soda        [Coca Cola]        2.18
# 3364      1349         2  Canned Soda        [Coca Cola]        2.18
# 1944       787         2  Canned Soda       [Dr. Pepper]        2.18
# 1092       450         2  Canned Soda        [Coca Cola]        2.18
# 350        150         2  Canned Soda        [Diet Coke]        2.18
# ...
