# %%
import folium # pip install folium
from folium import plugins
import ipywidgets
import geocoder # pip install geocoder
import geopy # pip install geopy
import numpy as np
import pandas as pd
from vega_datasets import data as vds # pip install vega_datasets

# %%
# route

# map
map_plot_route = folium.Map(location=[39.34817072809175, -0.3211988926656652], zoom_start=2)

# route_locs = ['Los Angeles', 'Las Vegas', 'Denver', 'Chicago', 'Manhattan']
# can use list of lists or list of tuples
route =[[39.34817072809175, -0.3211988926656652], [41.89036990745154, 12.492209439058682],
                   [40, 116],[27.175364300438453, 78.04219584029154], [30.32868588800269, 35.444426569239404],
                    [-22.95177766671126, -43.21045501764094],[-13.163031636078083, -72.54528356191474],
                    [20.679315636926955, -88.56827305620536],
                    [39.46222808587355, -0.3289908869179728]]

# add route to map
folium.PolyLine(route).add_to(map_plot_route)


folium.Marker(location=route[1], 
              popup='Coliseo Romano', 
              icon=folium.Icon(color='red', icon='landmark', prefix='fa')).add_to(map_plot_route)
              #EL PREFIX FA ES DE FRONT AWESOME, BUSCAMOS AHI Y CAMBIAMOS EN icon EL NOMBRE

folium.Marker(location=route[2], 
              popup='Muraña China', 
              icon=folium.Icon(color='beige', icon='vihara', prefix='fa')).add_to(map_plot_route)

folium.Marker(location=route[3], 
              popup='Taj Majal', 
              icon=folium.Icon(color='green', icon='mosque', prefix='fa')).add_to(map_plot_route)

folium.Marker(location=route[4], 
              popup='Petra', 
              icon=folium.Icon(color='pink', icon='dungeon', prefix='fa')).add_to(map_plot_route)

folium.Marker(location=route[5], 
              popup='Cristo Redentor', 
              icon=folium.Icon(color='blue', icon='cross', prefix='fa')).add_to(map_plot_route)

folium.Marker(location=route[6], 
              popup='Machu Pichu', 
              icon=folium.Icon(color='black', icon='mountain', prefix='fa')).add_to(map_plot_route)

folium.Marker(location=route[7], 
              popup='Chichen Itza', 
              icon=folium.Icon(color='orange', icon='campground', prefix='fa')).add_to(map_plot_route)

folium.Marker(location=route[8], 
              popup='Chichen Itza', 
              icon=folium.Icon(color='lightgray', icon='briefcase', prefix='fa')).add_to(map_plot_route)

folium.Marker(location=route[0], 
              popup='HOME', 
              icon=folium.Icon(color='lightblue', icon='house', prefix='fa')).add_to(map_plot_route)
              #EL PREFIX FA ES DE FRONT AWESOME, BUSCAMOS AHI Y CAMBIAMOS EN icon EL NOMBRE



# add ant path route to map
plugins.AntPath(route).add_to(map_plot_route )

# display map
map_plot_route
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
